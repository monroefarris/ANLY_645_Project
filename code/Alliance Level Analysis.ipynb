# %%
import networkx as nx
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np
from itertools import count

# %%
S1 = nx.Graph()
S1.add_nodes_from(['Richard','Kelly W.','Rudy','Susan','Sean','Colleen','Gervase','Jenna','Greg','Gretchen','Joel','Dirk','Ramona','Stacey','B.B.','Sonja'])

# %%
S1_edge_list = [('Richard','Rudy'),('Richard','Susan'),('Richard','Sean'),('Richard','Dirk'),('Richard','Kelly W.'),('Richard','Colleen'),('Kelly W.','Stacey'),('Kelly W.','Sonja'),('Kelly W.','Rudy'),('Kelly W.','Susan'),('Kelly W.','Sean'),('Kelly W.','Jenna'),('Kelly W.','Colleen'),('Rudy','Susan'),('Rudy','Sean'),('Rudy','Dirk'),('Rudy','Jenna'),('Susan','Sean'),('Susan','Dirk'),('Susan','Jenna'),('Sean','Dirk'),('Sean','Jenna'),('Colleen','Gervase'),('Colleen','Jenna'),('Colleen','Gretchen'),('Colleen','Joel'),('Colleen','Ramona'),('Colleen','Greg'),('Gervase','Jenna'),('Gervase','Gretchen'),('Gervase','Joel'),('Gervase','Ramona'),('Gervase','Greg'),('Jenna','Gretchen'),('Jenna','Joel'),('Jenna','Ramona'),('Jenna','Greg'),('Greg','B.B.'),('Greg','Gretchen'),('Gretchen','Joel'),('Gretchen','Ramona'),('Joel','Ramona'),('Stacey','Sonja')]

# %%
S1.add_edges_from(S1_edge_list)
S1['Richard']['Rudy']['weight'] = 9
S1['Richard']['Susan']['weight'] = 8
S1['Richard']['Sean']['weight'] = 4
S1['Richard']['Dirk']['weight'] = 1
S1['Richard']['Kelly W.']['weight'] = 6
S1['Richard']['Colleen']['weight'] = 1
S1['Kelly W.']['Stacey']['weight'] = 2
S1['Kelly W.']['Sonja']['weight'] = 1
S1['Kelly W.']['Rudy']['weight'] = 6
S1['Kelly W.']['Susan']['weight'] = 5
S1['Kelly W.']['Sean']['weight'] = 2
S1['Kelly W.']['Jenna']['weight'] = 1
S1['Kelly W.']['Colleen']['weight'] = 1
S1['Rudy']['Susan']['weight'] = 9
S1['Rudy']['Sean']['weight'] = 6
S1['Rudy']['Dirk']['weight'] = 2
S1['Rudy']['Jenna']['weight'] = 1
S1['Susan']['Sean']['weight'] = 6
S1['Susan']['Dirk']['weight'] = 2
S1['Susan']['Jenna']['weight'] = 1
S1['Sean']['Dirk']['weight'] = 2
S1['Sean']['Jenna']['weight'] = 1
S1['Colleen']['Gervase']['weight'] = 4
S1['Colleen']['Jenna']['weight'] = 4
S1['Colleen']['Gretchen']['weight'] = 3
S1['Colleen']['Joel']['weight'] = 2
S1['Colleen']['Ramona']['weight'] = 1
S1['Colleen']['Greg']['weight'] = 2
S1['Gervase']['Jenna']['weight'] = 2
S1['Gervase']['Gretchen']['weight'] = 1
S1['Gervase']['Joel']['weight'] = 2
S1['Gervase']['Ramona']['weight'] = 2
S1['Gervase']['Greg']['weight'] = 1
S1['Jenna']['Gretchen']['weight'] = 3
S1['Jenna']['Joel']['weight'] = 2
S1['Jenna']['Ramona']['weight'] = 1
S1['Jenna']['Greg']['weight'] = 1
S1['Greg']['B.B.']['weight'] = 1
S1['Greg']['Gretchen']['weight'] = 1
S1['Gretchen']['Joel']['weight'] = 2
S1['Gretchen']['Ramona']['weight'] = 1
S1['Joel']['Ramona']['weight'] = 1
S1['Stacey']['Sonja']['weight'] = 1

# %%
S1_attributes = {'Richard':{'days':39,"gender":"Male"},'Kelly W':{'days':39,"gender":"Female"},'Rudy':{'days':38,"gender":"Male"},'Susan':{'days':37,"gender":"Female"},'Sean':{'days':36,"gender":"Male"},'Colleen':{'days':33,"gender":"Female"},'Gervase':{'days':30,"gender":"Male"},'Jenna':{'days':27,"gender":"Female"},'Greg':{'days':24,"gender":"Male"},'Gretchen':{'days':21,"gender":"Female"},'Joel':{'days':21,"gender":"Male"},'Dirk':{'days':18,"gender":"Male"},'Ramona':{'days':12,"gender":"Female"},'Stacey':{'days':9,"gender":"Female"},'B.B.':{'days':6,"gender":"Male"},'Sonja':{'days':3,"gender":"Female"}}

# %%
nx.set_node_attributes(S1, S1_attributes)

# %%
pos=nx.circular_layout(S1) # pos = nx.nx_agraph.graphviz_layout(G)
nx.draw_networkx(S1,pos)
labels = nx.get_edge_attributes(S1,'weight')
nx.draw_networkx_edge_labels(S1,pos,edge_labels=labels)
# Out:
# {('Richard', 'Rudy'): Text(0.8535533853789601, 0.35355337681103954, '9'),
#  ('Richard', 'Susan'): Text(0.69134172973507, 0.4619397437513753, '8'),
#  ('Richard', 'Sean'): Text(0.49999998100027926, 0.49999999143207896, '4'),
#  ('Richard', 'Dirk'): Text(0.3086582163722321, -0.46193972537294775, '1'),
#  ('Richard', 'Kelly W.'): Text(0.9619397523192958, 0.19134172116714945, '6'),
#  ('Richard', 'Colleen'): Text(0.3086583057791987, 0.46193977355369753, '1'),
#  ('Kelly W.', 'Stacey'): Text(0.6532815416590108, -0.27059799849385097, '2'),
#  ('Kelly W.', 'Sonja'): Text(0.9238795344409145, 9.189213778793004e-09, '1'),
#  ('Kelly W.', 'Rudy'): Text(0.8154931376982565, 0.5448951036901364, '6'),
#  ('Kelly W.', 'Susan'): Text(0.6532814820543664, 0.6532814706304721, '5'),
#  ('Kelly W.', 'Sean'): Text(0.4619397333195756, 0.6913417183111757, '2'),
#  ('Kelly W.', 'Jenna'): Text(5.7119469709654425e-09, 0.3826834629474073, '1'),
# ...

# %%
S19 = nx.Graph()
S19.add_nodes_from(['Natalie','Russell H.','Mick','Brett','Jaison','Shambo','Monica','Dave','John','Laura','Kelly','Erik',
                    'Liz','Russell S.','Ashley','Yasmin','Ben','Betsy','Mike','Marisa'])

# %%
S19_edge_list = [('Natalie','Russell H.'),('Natalie','Jaison'),('Natalie','Liz'),('Natalie','Ashley'),('Natalie','Ben'),('Natalie','Mike'),('Natalie','Mick'),('Natalie','Brett'),('Natalie','Monica'),('Natalie','Dave'),('Natalie','John'),('Natalie','Laura'),('Natalie','Kelly'),('Natalie','Shambo'),('Russell H.','Jaison'),('Russell H.','Liz'),('Russell H.','Ashley'),('Russell H.','Ben'),('Russell H.','Mike'),('Russell H.','Mick'),('Russell H.','Brett'),('Russell H.','Monica'),('Russell H.','Dave'),('Russell H.','John'),('Russell H.','Laura'),('Russell H.','Kelly'),('Russell H.','Shambo'),('Mick','Betsy'),('Mick','Marisa'),('Mick','Jaison'),('Mick','Liz'),('Mick','Ashley'),('Mick','Ben'),('Mick','Yasmin'),('Mick','Brett'),('Mick','Monica'),('Mick','Dave'),('Mick','John'),('Mick','Laura'),('Mick','Kelly'),('Mick','Shambo'),('Brett','Monica'),('Brett','Dave'),('Brett','John'),('Brett','Laura'),('Brett','Kelly'),('Brett','Erik'),('Brett','Russell S.'),('Brett','Jaison'),('Brett','Shambo'),('Jaison','Liz'),('Jaison','Ashley'),('Jaison','Ben'),('Jaison','Betsy'),('Jaison','Marisa'),('Jaison','Monica'),('Jaison','Dave'),('Jaison','John'),('Jaison','Laura'),('Jaison','Kelly'),('Jaison','Shambo'),('Shambo','Yasmin'),('Shambo','Erik'),('Shambo','Monica'),('Shambo','Dave'),('Shambo','John'),('Shambo','Laura'),('Shambo','Kelly'),('Monica','Dave'),('Monica','John'),('Monica','Laura'),('Monica','Kelly'),('Monica','Erik'),('Monica','Russell S.'),('Dave','John'),('Dave','Laura'),('Dave','Kelly'),('Dave','Erik'),('Dave','Russell S.'),('John','Laura'),('John','Kelly'),('John','Erik'),('John','Russell S.'),('Laura','Kelly'),('Laura','Erik'),('Laura','Russell S.'),('Kelly','Erik'),('Kelly','Russell S.'),('Erik','Russell S.'),('Liz','Ashley'),('Liz','Ben'),('Liz','Mike'),('Ashley','Ben'),('Ashley','Mike'),('Ben','Mike'),('Betsy','Marisa')]

# %%
S19.add_edges_from(S19_edge_list)
S19['Natalie']['Russell H.']['weight'] = 14
S19['Natalie']['Jaison']['weight'] = 12
S19['Natalie']['Liz']['weight'] = 4
S19['Natalie']['Ashley']['weight'] = 3
S19['Natalie']['Ben']['weight'] = 2
S19['Natalie']['Mike']['weight'] = 1
S19['Natalie']['Mick']['weight'] = 13
S19['Natalie']['Brett']['weight'] = 5
S19['Natalie']['Monica']['weight'] = 3
S19['Natalie']['Dave']['weight'] = 2
S19['Natalie']['John']['weight'] = 1
S19['Natalie']['Laura']['weight'] = 1
S19['Natalie']['Kelly']['weight'] = 1
S19['Natalie']['Shambo']['weight'] = 3
S19['Russell H.']['Jaison']['weight'] = 12
S19['Russell H.']['Liz']['weight'] = 4
S19['Russell H.']['Ashley']['weight'] = 3
S19['Russell H.']['Ben']['weight'] = 2
S19['Russell H.']['Mike']['weight'] = 1
S19['Russell H.']['Mick']['weight'] = 13
S19['Russell H.']['Brett']['weight'] = 5
S19['Russell H.']['Monica']['weight'] = 3
S19['Russell H.']['Dave']['weight'] = 2
S19['Russell H.']['John']['weight'] = 1
S19['Russell H.']['Laura']['weight'] = 1
S19['Russell H.']['Kelly']['weight'] = 1
S19['Russell H.']['Shambo']['weight'] = 3
S19['Mick']['Betsy']['weight'] = 1
S19['Mick']['Marisa']['weight'] = 1
S19['Mick']['Jaison']['weight'] = 11
S19['Mick']['Liz']['weight'] = 3
S19['Mick']['Ashley']['weight'] = 1
S19['Mick']['Ben']['weight'] = 1
S19['Mick']['Yasmin']['weight'] = 1
S19['Mick']['Brett']['weight'] = 5
S19['Mick']['Monica']['weight'] = 3
S19['Mick']['Dave']['weight'] = 2
S19['Mick']['John']['weight'] = 1
S19['Mick']['Laura']['weight'] = 1
S19['Mick']['Kelly']['weight'] = 1
S19['Mick']['Shambo']['weight'] = 3
S19['Brett']['Monica']['weight'] = 7
S19['Brett']['Dave']['weight'] = 5
S19['Brett']['John']['weight'] = 4
S19['Brett']['Laura']['weight'] = 4
S19['Brett']['Kelly']['weight'] = 3
S19['Brett']['Erik']['weight'] = 2
S19['Brett']['Russell S.']['weight'] = 1
S19['Brett']['Jaison']['weight'] = 4
S19['Brett']['Shambo']['weight'] = 1
S19['Jaison']['Liz']['weight'] = 4
S19['Jaison']['Ashley']['weight'] = 3
S19['Jaison']['Ben']['weight'] = 2
S19['Jaison']['Betsy']['weight'] = 1
S19['Jaison']['Marisa']['weight'] = 1
S19['Jaison']['Monica']['weight'] = 3
S19['Jaison']['Dave']['weight'] = 2
S19['Jaison']['John']['weight'] = 2
S19['Jaison']['Laura']['weight'] = 1
S19['Jaison']['Kelly']['weight'] = 1
S19['Jaison']['Shambo']['weight'] = 3
S19['Shambo']['Yasmin']['weight'] = 1
S19['Shambo']['Erik']['weight'] = 2
S19['Shambo']['Monica']['weight'] = 2
S19['Shambo']['Dave']['weight'] = 1
S19['Shambo']['John']['weight'] = 2
S19['Shambo']['Laura']['weight'] = 1
S19['Shambo']['Kelly']['weight'] = 1
S19['Monica']['Dave']['weight'] = 4
S19['Monica']['John']['weight'] = 4
S19['Monica']['Laura']['weight'] = 4
S19['Monica']['Kelly']['weight'] = 3
S19['Monica']['Erik']['weight'] = 1
S19['Monica']['Russell S.']['weight'] = 1
S19['Dave']['John']['weight'] = 4
S19['Dave']['Laura']['weight'] = 4
S19['Dave']['Kelly']['weight'] = 3
S19['Dave']['Erik']['weight'] = 1
S19['Dave']['Russell S.']['weight'] = 1
S19['John']['Laura']['weight'] = 4
S19['John']['Kelly']['weight'] = 3
S19['John']['Erik']['weight'] = 1
S19['John']['Russell S.']['weight'] = 1
S19['Laura']['Kelly']['weight'] = 3
S19['Laura']['Erik']['weight'] = 1
S19['Laura']['Russell S.']['weight'] = 1
S19['Kelly']['Erik']['weight'] = 1
S19['Kelly']['Russell S.']['weight'] = 1
S19['Erik']['Russell S.']['weight'] = 1
S19['Liz']['Ashley']['weight'] = 3
S19['Liz']['Ben']['weight'] = 2
S19['Liz']['Mike']['weight'] = 1
S19['Ashley']['Ben']['weight'] = 2
S19['Ashley']['Mike']['weight'] = 1
S19['Ben']['Mike']['weight'] = 1
S19['Betsy']['Marisa']['weight'] = 1

# %%
S19_attributes = {'Natalie':{'days':39,"gender":"Female"},'Russell H.':{'days':39,"gender":"Male"},'Mick':{'days':38,"gender":"Male"},'Brett':{'days':37,"gender":"Male"},'Brett':{'days':37,"gender":"Male"},'Jaison':{'days':36,"gender":"Male"},'Shambo':{'days':33,"gender":"Female"},'Monica':{'days':30,"gender":"Female"},'Dave':{'days':28,"gender":"Male"},'John':{'days':26,"gender":"Male"},'Laura':{'days':24,"gender":"Female"},'Kelly':{'days':22,"gender":"Female"},'Erik':{'days':20,"gender":"Male"},'Liz':{'days':18,"gender":"Female"},'Russell S.':{'days':16,"gender":"Male"},'Ashley':{'days':14,"gender":"Female"},'Yasmin':{'days':12,"gender":"Female"},'Ben':{'days':10,"gender":"Male"},'Betsy':{'days':9,"gender":"Female"},'Mike':{'days':6,"gender":"Male"},'Marisa':{'days':3,"gender":"Female"}}

# %%
nx.set_node_attributes(S19, S19_attributes)

# %%
pos=nx.circular_layout(S19) # pos = nx.nx_agraph.graphviz_layout(G)
nx.draw_networkx(S19,pos)
labels = nx.get_edge_attributes(S19,'weight')
nx.draw_networkx_edge_labels(S19,pos,edge_labels=labels)
# Out:
# {('Natalie',
#   'Russell H.'): Text(0.9755282586094334, 0.15450851254631864, '14'),
#  ('Natalie', 'Jaison'): Text(0.65450847926673, 0.4755282769878611, '12'),
#  ('Natalie', 'Liz'): Text(0.0954915288292052, -0.29389263457225495, '4'),
#  ('Natalie', 'Ashley'): Text(0.34549143609428035, -0.4755282205618684, '3'),
#  ('Natalie', 'Ben'): Text(0.6545085537725349, -0.4755282205618684, '2'),
#  ('Natalie', 'Mike'): Text(0.9045084610376101, -0.29389263457225495, '1'),
#  ('Natalie', 'Mick'): Text(0.9045084908399321, 0.2938926313936037, '13'),
#  ('Natalie', 'Brett'): Text(0.793892613015176, 0.4045085092183598, '5'),
#  ('Natalie', 'Monica'): Text(0.3454914807977634, 0.47552824718553915, '3'),
#  ('Natalie', 'Dave'): Text(0.20610737685163927, 0.4045085092183598, '2'),
#  ('Natalie', 'John'): Text(0.0954914990268832, 0.2938926313936037, '1'),
#  ('Natalie', 'Laura'): Text(0.02447176105970389, 0.15450852744747964, '1'),
#  ('Natalie',
# ...

# %%
S36 = nx.Graph()
S36.add_nodes_from(['Wendell','Domenick','Laurel','Angela','Donathan','Sebastian','Kellyn','Chelsea','Michael',
                    'Jenna','Desiree','Libby','Chris','Bradley','James','Stephanie','Brendan','Morgan','Jacob','Gonzalez'])

# %%
S36_edge_list = [('Wendell','Domenick'),('Wendell','Morgan'),('Wendell','Laurel'),('Wendell','Donathan'),('Wendell','Sebastian'),('Wendell','Kellyn'),('Wendell','Chelsea'),('Wendell','Michael'),('Wendell','Jenna'),('Wendell','Libby'),('Wendell','Angela'),('Domenick','Morgan'),('Domenick','Donathan'),('Domenick','Chelsea'),('Domenick','Libby'),('Domenick','Laurel'),('Domenick','Sebastian'),('Domenick','Kellyn'),('Domenick','Michael'),('Domenick','Jenna'),('Domenick','Angela'),('Laurel','Donathan'),('Laurel','Michael'),('Laurel','Jenna'),('Laurel','Libby'),('Laurel','James'),('Laurel','Stephanie'),('Laurel','Brendan'),('Laurel','Sebastian'),('Laurel','Kellyn'),('Laurel','Chelsea'),('Laurel','Desiree'),('Laurel','Angela'),('Angela','Kellyn'),('Angela','Michael'),('Angela','Desiree'),('Angela','Donathan'),('Angela','Sebastian'),('Angela','Jenna'),('Angela','Libby'),('Angela','Chelsea'),('Donathan','Michael'),('Donathan','Jenna'),('Donathan','Libby'),('Donathan','James'),('Donathan','Stephanie'),('Donathan','Brendan'),('Donathan','Chelsea'),('Donathan','Sebastian'),('Donathan','Kellyn'),('Sebastian','Kellyn'),('Sebastian','Chelsea'),('Sebastian','Desiree'),('Sebastian','Bradley'),('Sebastian','Michael'),('Sebastian','Jenna'),('Sebastian','Libby'),('Kellyn','Chelsea'),('Kellyn','Desiree'),('Kellyn','Bradley'),('Kellyn','Michael'),('Kellyn','Jenna'),('Kellyn','Libby'),('Chelsea','Desiree'),('Chelsea','Bradley'),('Chelsea','Michael'),('Chelsea','Jenna'),('Chelsea','Libby'),('Michael','Jenna'),('Michael','Libby'),('Michael','James'),('Michael','Stephanie'),('Michael','Brendan'),('Michael','Desiree'),('Michael','Bradley'),('Jenna','Libby'),('Jenna','James'),('Jenna','Stephanie'),('Jenna','Brendan'),('Jenna','Desiree'),('Jenna','Bradley'),('Desiree','Bradley'),('Libby','James'),('Libby','Stephanie'),('Libby','Brendan'),('James','Stephanie'),('James','Brendan'),('Stephanie','Brendan')]

# %%
S36.add_edges_from(S36_edge_list)
S36['Wendell']['Domenick']['weight'] = 12
S36['Wendell']['Morgan']['weight'] = 1
S36['Wendell']['Laurel']['weight'] = 7
S36['Wendell']['Donathan']['weight'] = 3
S36['Wendell']['Sebastian']['weight'] = 3
S36['Wendell']['Kellyn']['weight'] = 3
S36['Wendell']['Chelsea']['weight'] = 2
S36['Wendell']['Michael']['weight'] = 2
S36['Wendell']['Jenna']['weight'] = 3
S36['Wendell']['Libby']['weight'] = 2
S36['Wendell']['Angela']['weight'] = 2
S36['Domenick']['Morgan']['weight'] = 1
S36['Domenick']['Donathan']['weight'] = 4
S36['Domenick']['Chelsea']['weight'] = 2
S36['Domenick']['Libby']['weight'] = 3
S36['Domenick']['Laurel']['weight'] = 7
S36['Domenick']['Sebastian']['weight'] = 3
S36['Domenick']['Kellyn']['weight'] = 3
S36['Domenick']['Michael']['weight'] = 2
S36['Domenick']['Jenna']['weight'] = 3
S36['Domenick']['Angela']['weight'] = 2
S36['Laurel']['Donathan']['weight'] = 3
S36['Laurel']['Michael']['weight'] = 3
S36['Laurel']['Jenna']['weight'] = 4
S36['Laurel']['Libby']['weight'] = 3
S36['Laurel']['James']['weight'] = 3
S36['Laurel']['Stephanie']['weight'] = 2
S36['Laurel']['Brendan']['weight'] = 2
S36['Laurel']['Sebastian']['weight'] = 2
S36['Laurel']['Kellyn']['weight'] = 3
S36['Laurel']['Chelsea']['weight'] = 2
S36['Laurel']['Desiree']['weight'] = 1
S36['Laurel']['Angela']['weight'] = 1
S36['Angela']['Kellyn']['weight'] = 1
S36['Angela']['Michael']['weight'] = 1
S36['Angela']['Desiree']['weight'] = 2
S36['Angela']['Donathan']['weight'] = 1
S36['Angela']['Sebastian']['weight'] = 3
S36['Angela']['Jenna']['weight'] = 1
S36['Angela']['Libby']['weight'] = 1
S36['Angela']['Chelsea']['weight'] = 2
S36['Donathan']['Michael']['weight'] = 3
S36['Donathan']['Jenna']['weight'] = 4
S36['Donathan']['Libby']['weight'] = 5
S36['Donathan']['James']['weight'] = 2
S36['Donathan']['Stephanie']['weight'] = 1
S36['Donathan']['Brendan']['weight'] = 1
S36['Donathan']['Chelsea']['weight'] = 3
S36['Donathan']['Sebastian']['weight'] = 4
S36['Donathan']['Kellyn']['weight'] = 2
S36['Sebastian']['Kellyn']['weight'] = 5
S36['Sebastian']['Chelsea']['weight'] = 4
S36['Sebastian']['Desiree']['weight'] = 2
S36['Sebastian']['Bradley']['weight'] = 2
S36['Sebastian']['Michael']['weight'] = 3
S36['Sebastian']['Jenna']['weight'] = 4
S36['Sebastian']['Libby']['weight'] = 2
S36['Kellyn']['Chelsea']['weight'] = 4
S36['Kellyn']['Desiree']['weight'] = 4
S36['Kellyn']['Bradley']['weight'] = 2
S36['Kellyn']['Michael']['weight'] = 4
S36['Kellyn']['Jenna']['weight'] = 3
S36['Kellyn']['Libby']['weight'] = 1
S36['Chelsea']['Desiree']['weight'] = 4
S36['Chelsea']['Bradley']['weight'] = 2
S36['Chelsea']['Michael']['weight'] = 2
S36['Chelsea']['Jenna']['weight'] = 2
S36['Chelsea']['Libby']['weight'] = 2
S36['Michael']['Jenna']['weight'] = 5
S36['Michael']['Libby']['weight'] = 3
S36['Michael']['James']['weight'] = 1
S36['Michael']['Stephanie']['weight'] = 2
S36['Michael']['Brendan']['weight'] = 2
S36['Michael']['Desiree']['weight'] = 2
S36['Michael']['Bradley']['weight'] = 1
S36['Jenna']['Libby']['weight'] = 3
S36['Jenna']['James']['weight'] = 2
S36['Jenna']['Stephanie']['weight'] = 3
S36['Jenna']['Brendan']['weight'] = 3
S36['Jenna']['Desiree']['weight'] = 1
S36['Jenna']['Bradley']['weight'] = 1
S36['Desiree']['Bradley']['weight'] = 2
S36['Libby']['James']['weight'] = 2
S36['Libby']['Stephanie']['weight'] = 1
S36['Libby']['Brendan']['weight'] = 1
S36['James']['Stephanie']['weight'] = 2
S36['James']['Brendan']['weight'] = 2
S36['Stephanie']['Brendan']['weight'] = 3

# %%
S36_attributes = {'Wendell':{'days':39,"gender":"Male"},'Domenick':{'days':39,"gender":"Male"},'Laurel':{'days':39,"gender":"Female"},'Angela':{'days':38,"gender":"Female"},'Donathan':{'days':37,"gender":"Male"},'Sebastian':{'days':36,"gender":"Male"},'Kellyn':{'days':33,"gender":"Female"},'Chelsea':{'days':32,"gender":"Female"},'Michael':{'days':30,"gender":"Male"},'Jenna':{'days':27,"gender":"Female"},'Desiree':{'days':25,"gender":"Female"},'Libby':{'days':22,"gender":"Female"},'Chris':{'days':20,"gender":"Male"},'Bradley':{'days':17,"gender":"Male"},'James':{'days':15,"gender":"Male"},'Stephanie':{'days':13,"gender":"Female"},'Brendan':{'days':11,"gender":"Male"},'Morgan':{'days':8,"gender":"Female"},'Jacob':{'days':6,"gender":"Male"},'Gonzalez':{'days':3,"gender":"Male"}}

# %%
nx.set_node_attributes(S36,S36_attributes)

# %%
pos=nx.circular_layout(S36) # pos = nx.nx_agraph.graphviz_layout(G)
nx.draw_networkx(S36,pos)
labels = nx.get_edge_attributes(S36,'weight')
nx.draw_networkx_edge_labels(S36,pos,edge_labels=labels)
# Out:
# {('Wendell', 'Domenick'): Text(0.9755282586094334, 0.15450851254631864, '12'),
#  ('Wendell', 'Morgan'): Text(0.7938925236082099, -0.404508542199333, '1'),
#  ('Wendell', 'Laurel'): Text(0.9045084908399321, 0.2938926313936037, '7'),
#  ('Wendell', 'Donathan'): Text(0.65450847926673, 0.4755282769878611, '3'),
#  ('Wendell', 'Sebastian'): Text(0.49999997307771377, 0.5000000066559177, '3'),
#  ('Wendell', 'Kellyn'): Text(0.3454914807977634, 0.47552824718553915, '3'),
#  ('Wendell', 'Chelsea'): Text(0.20610737685163927, 0.4045085092183598, '2'),
#  ('Wendell', 'Michael'): Text(0.0954914990268832, 0.2938926313936037, '2'),
#  ('Wendell', 'Jenna'): Text(0.02447176105970389, 0.15450852744747964, '3'),
#  ('Wendell', 'Libby'): Text(0.02447173125738189, -0.15450847102148693, '2'),
#  ('Wendell', 'Angela'): Text(0.793892613015176, 0.4045085092183598, '2'),
#  ('Domenick', 'Morgan'): Text(0.7694207939401534, -0.2500000429648498, '1'),
# ...

# %%
nx.write_gml(S1, "./S1.gml")
nx.write_gml(S19, "./S19.gml")
nx.write_gml(S36, "./S36.gml")
